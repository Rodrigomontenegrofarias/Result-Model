# %%
from getpass import getpass
import os

os.environ['USER'] = "Rodrigomontenegrofarias"
os.environ['PASSWORD'] = getpass('Enter the password of your Github account: ')
os.environ['REPOSITORY'] = "result"
os.environ['GITHUB_AUTH'] = os.environ['USER'] + ':' + os.environ['PASSWORD']

# !rm -rf $REPOSITORY # To remove the previous clone of the Github repository
# !git clone https://$GITHUB_AUTH@github.com/$USER/$REPOSITORY.git 

os.environ['USER'] = os.environ['PASSWORD'] = os.environ['REPOSITORY'] = os.environ['GITHUB_AUTH'] = ""


# ingresos de bases de datos guarddadas mediante git
# Out:
# Enter the password of your Github account: ········
# Cloning into 'result'...
# remote: Enumerating objects: 369, done.
# remote: Total 369 (delta 0), reused 0 (delta 0), pack-reused 369
# Receiving objects: 100% (369/369), 19.08 MiB | 15.69 MiB/s, done.
# Resolving deltas: 100% (171/171), done.

# %%
#cargamos librerias
import pandas as pd
import numpy as np
#graficas
import matplotlib.pylab as plt
# %matplotlib inline
plt.rcParams['figure.figsize'] = (16,9)
plt.style.use('fast')
#ver redes neuronales

#sklear para ver modelos machine learning
from sklearn.preprocessing import MinMaxScaler
# %matplotlib inline

import matplotlib.pyplot as plt
# plt.xkcd()
# plt.style.use('ggplot')
# %matplotlib inline

import matplotlib as mpl
mpl.rcParams['figure.figsize'] = (20, 8)

# %% [markdown]
# # Ingreso de bases de datos y coneccion a drive.

# %%
# !git config user.email "rodrigo.montenegro@alumnos.uv.cl"

# !git config user.name "Rodrigomontenegrofarias"
# Out:
# fatal: not in a git directory
# fatal: not in a git directory

# %%
ls
# Out:
#  Copia_de_Resultados_final.ipynb
#  DATABASE-PRIVATE/
#  exp-10.ipynb
#  exp-1.ipynb
#  exp-2.ipynb
#  exp-3.ipynb
#  exp-4.ipynb
#  exp-5.ipynb
#  exp-6.ipynb
#  exp-7.ipynb
#  exp-8.ipynb
#  exp-9.ipynb
#  Experimento10_Complemento_Lekouch.ipynb
#  Experimento1_Complemento_Lekouch.ipynb
#  Experimento2_Complemento_Lekouch.ipynb
#  Experimento3_Complemento_Lekouch.ipynb
#  Experimento4_Complemento_Lekouch.ipynb
#  Experimento5_Complemento_Lekouch.ipynb
#  Experimento6_Complemento_Lekouch.ipynb
#  Experimento7_Complemento_Lekouch.ipynb
#  Experimento8_Complemento_Lekouch.ipynb
#  Experimento9_Complemento_Lekouch.ipynb
# 'guardar modelos ejecutados.ipynb'
# 'guardar modelos ejecutados-LM.ipynb'
#  requirements.txt
#  result/
#  Untitled.ipynb

# %%
cd result/
# Out:
# /root/notebooks/result

# %%
# solo el primer se encuentra en kl/h se debe cambiar a m/S

##Imprlementar desde github:

datos1=pd.read_csv('Prueba-1.0.csv',decimal=",", encoding='utf-8',sep=u',')
datos2=pd.read_csv('Prueba-2.0.csv',decimal=",",sep=u',', encoding='utf-8', dayfirst=True)
datos3=pd.read_csv('Prueba-3.0.csv',decimal=",",sep=u',', encoding='utf-8', dayfirst=True)
datos4=pd.read_csv('Prueba-4.0.csv',decimal=",",sep=u',', encoding='utf-8', dayfirst=True)
datos5=pd.read_csv('Prueba-5.0.csv',decimal=",",sep=u',', encoding='utf-8', dayfirst=True)
datos6=pd.read_csv('Prueba-6.0.csv',decimal=",",sep=u',', encoding='utf-8', dayfirst=True)
datos7=pd.read_csv('Prueba-7.0.csv',decimal=",",sep=u',', encoding='utf-8',  dayfirst=True)
datos8=pd.read_csv('Prueba-8.0.csv',decimal=",",sep=u',', encoding='utf-8', dayfirst=True)
datos9=pd.read_csv('Prueba-9.0.csv',decimal=",",sep=u',', encoding='utf-8', dayfirst=True)
datos10=pd.read_csv('Prueba-10.0.csv',decimal=",",sep=u',', encoding='utf-8',dayfirst=True)

#datos11=pd.read_csv('/content/Rodrigomontenegrofarias/resultados/Prueba11.0.csv',decimal=",",sep=u',', encoding='utf-8',  dayfirst=True)
#datos12=pd.read_csv('/content/Rodrigomontenegrofarias/resultados/Prueba12.0.csv',decimal=",",sep=u',', encoding='utf-8', dayfirst=True)
#datos13=pd.read_csv('/content/Rodrigomontenegrofarias/Prueba13.0.csv',decimal=",",sep=u',', encoding='utf-8',  dayfirst=True)
#datos14=pd.read_csv('/content/Rodrigomontenegrofarias/Prueba14.0.csv',decimal=",",sep=u',', encoding='utf-8',  dayfirst=True)
#datos15=pd.read_csv('/content/Rodrigomontenegrofarias/Prueba15.0.csv',decimal=",",sep=u',', encoding='utf-8',  dayfirst=True)
#datos16=pd.read_csv('/content/Rodrigomontenegrofarias/Prueba16.0.csv',decimal=",",sep=u',', encoding='utf-8',  dayfirst=True)
#datos17=pd.read_csv('/content/Rodrigomontenegrofarias/Prueba17.0.csv',decimal=",",sep=u',', encoding='utf-8',  dayfirst=True)
#datos18=pd.read_csv('/content/Rodrigomontenegrofarias/Prueba18.0.csv',decimal=",",sep=u',', encoding='utf-8', dayfirst=True)
#datos19=pd.read_csv('/content/Rodrigomontenegrofarias/Prueba19.0.csv',decimal=",",sep=u',', encoding='utf-8',  dayfirst=True)
#datos20=pd.read_csv('/content/Rodrigomontenegrofarias/Prueba20.0.csv',decimal=",",sep=u',', encoding='utf-8', dayfirst=True)
#Fecha
#datos1 = datos1.rename(columns={'Gust(km/h)':'Gust(m/s)'})
#datos1 = datos1.rename(columns={'Wind Speed(km/h)':'Wind Speed(m/s)'})


#df.columns
#Gust(km/h)
 
datos1
# Out:
#    Unnamed: 0 Pruebas        coef(a)_LM-PD       rsquared_LM-PD  \
# 0           0     1.0  0.37703252592072023  0.08512112404899186
#
#   Standard Error_LM-PD        coef(b)_LM-PD  coef(a)_Acu-LM-PD  \
# 0  0.11190820539299455  0.04356022491168253  2.329097041612987
#
#    rsquared_Acu-LM-PD Standard Error_Acu-LM-PD     coef(b)_Acu-LM-PD  \
# 0  0.9584788286856828     0.043888547307611964  0.023148667060888167
#
#         coef(a)LM-6AM       rsquaredLM-6AM Standard ErrorLM-6AM  \
# 0  0.4729697158637946  0.31415350653936647  0.06326972495077322
#
#           coef(b)LM-6AM  coef(a)_Acu-LM-6AM rsquared_Acu-LM-6AM  \
# 0  0.020386479279997878  1.5527230010292106  0.9777193252378551
#
#   Standard Error_Acu-LM-6AM   coef(b)_Acu-LM-6AM
# 0      0.021221258778893044  -0.1675122552983267

# %%
datos1
# Out:
#    Unnamed: 0 Pruebas        coef(a)_LM-PD       rsquared_LM-PD  \
# 0           0     1.0  0.37703252592072023  0.08512112404899186
#
#   Standard Error_LM-PD        coef(b)_LM-PD  coef(a)_Acu-LM-PD  \
# 0  0.11190820539299455  0.04356022491168253  2.329097041612987
#
#    rsquared_Acu-LM-PD Standard Error_Acu-LM-PD     coef(b)_Acu-LM-PD  \
# 0  0.9584788286856828     0.043888547307611964  0.023148667060888167
#
#         coef(a)LM-6AM       rsquaredLM-6AM Standard ErrorLM-6AM  \
# 0  0.4729697158637946  0.31415350653936647  0.06326972495077322
#
#           coef(b)LM-6AM  coef(a)_Acu-LM-6AM rsquared_Acu-LM-6AM  \
# 0  0.020386479279997878  1.5527230010292106  0.9777193252378551
#
#   Standard Error_Acu-LM-6AM   coef(b)_Acu-LM-6AM
# 0      0.021221258778893044  -0.1675122552983267

# %%
#datostotal = [datos1,datos2,datos3,datos4,datos5,datos6,datos7,datos8,datos9,datos10,datos11,datos12,datos13,datos14,datos15,datos16,datos17,datos18,datos19,datos20, ]
datostotal = [datos1,datos2,datos3,datos4,datos5,datos6,datos7,datos8,datos9,datos10,]
#datostotal = [datos1,datos2,datos3,datos4,datos5,datos6,datos10,datos11,datos12,datos13,datos14,datos15,datos16,datos17,datos18,datos19,datos20, ]
resultadoDatos= pd.concat(datostotal)

# %%
resultadoDatos
# Out:
#    Unnamed: 0 Pruebas        coef(a)_LM-PD       rsquared_LM-PD  \
# 0           0     1.0  0.37703252592072023  0.08512112404899186
# 0           0     2.0   0.3867821373825421  0.08180978199749678
# 0           0     3.0   0.4051920261794425  0.09783583344846214
# 0           0     4.0   0.4665648174852598  0.18265822749867155
# 0           0     5.0  0.47992266515437054  0.21677040713661777
# 0           0     6.0   0.4874132174073801   0.1265008147451705
# 0           0     7.0   0.4121009281780039  0.11484709684229621
# 0           0     8.0   0.5493491292053688  0.12296925272001713
# 0           0     9.0   0.4284785530093785  0.24878858372413415
# 0           0    10.0   0.4220670615046133   0.1079792353803547
#
#   Standard Error_LM-PD         coef(b)_LM-PD   coef(a)_Acu-LM-PD  \
# 0  0.11190820539299455   0.04356022491168253   2.329097041612987
# 0  0.11731409852361847   0.04868962747631995  2.5466827254823032
# 0  0.11139732993876565  0.046395791025820234  2.4597303377677338
# 0  0.08935407028801604   0.04329342193249256  2.4289276696466993
# 0  0.08259159705805605   0.04190166665780069  2.4279217975563165
# 0  0.11595833994615941  0.045266848965784895  2.4866028538338547
# 0  0.10357928565143176   0.04244918029588969   2.274813582653427
# 0   0.1328243629885543  0.047353695888071985    2.65203323426935
# 0  0.06740856578823798   0.04625499602607915   2.515338488130535
# 0  0.10982947897581036   0.04588216294504918   2.452319484612608
#
#    rsquared_Acu-LM-PD Standard Error_Acu-LM-PD     coef(b)_Acu-LM-PD  \
# 0  0.9584788286856828     0.043888547307611964  0.023148667060888167
# 0  0.9604224588505625     0.046804561220096984   0.10235605579412571
# 0  0.9618958009886267       0.0443230855755955   0.11317832470255237
# 0  0.9696262512443365      0.03892079314533659  -0.09856191502913624
# 0  0.9638060236214812     0.042596911380505656   -0.2261418876678098
# 0  0.9671991034825086      0.04145829406477406   0.12565939404488274
# 0  0.9624329254648296       0.0406896868658154   0.14179160414293435
# 0  0.9731328293436551     0.039895503741941715   0.13573411191993723
# 0  0.9707050672138159      0.03956117002272083  -0.21044575664261042
# 0  0.9605860016249447      0.04497324818993615   0.10419867119202167
#
#          coef(a)LM-6AM       rsquaredLM-6AM  Standard ErrorLM-6AM  \
# 0   0.4729697158637946  0.31415350653936647   0.06326972495077322
# 0   0.5061104912194738  0.30848008571712904   0.06860475633737935
# 0   0.5420916101331033  0.29467659445146455    0.0759301211499239
# 0   0.5111806483292063   0.3941339038919277  0.057380052743199544
# 0   0.4993880814142323  0.33445599443796337   0.06377891728142009
# 0    0.512884020732219  0.41684450570237197   0.05492175399318126
# 0   0.5628664641978992  0.35004218703030354   0.06943970214697862
# 0   0.4059512047792896   0.2769971604334439   0.05937809934684615
# 0   0.4996672107864814   0.2977908220382339     0.069466997899334
# 0  0.49723686066159123   0.3920803183074232   0.05605559831134126
#
#           coef(b)LM-6AM  coef(a)_Acu-LM-6AM rsquared_Acu-LM-6AM  \
# 0  0.020386479279997878  1.5527230010292106  0.9777193252378551
# 0  0.018525475441270076  1.5219274454104093  0.9683365536839611
# 0  0.019632328312293355  1.6308490058281102  0.9693968345589337
# 0   0.02584103431996239   1.824528379553309  0.9765941754643223
# 0  0.033519542509459155   2.151267957270182  0.9738692529000084
# 0   0.02336198202456177  1.7241163573214373   0.979503717459855
# 0  0.024102209029564454  1.8338313125102912  0.9824383500734654
# 0   0.01756969771248876   1.344200962591671  0.9784630177604735
# 0   0.03313271310442592  2.1080926412955963  0.9752682598922348
# 0  0.020519750807859675  1.5714518022282813  0.9746161499620642
#
#   Standard Error_Acu-LM-6AM    coef(b)_Acu-LM-6AM
# 0      0.021221258778893044   -0.1675122552983267
# 0      0.024916094000327935  -0.14762601570257394
# 0      0.026234102656054786  -0.19017490092471495
# 0      0.025572643014294794  -0.12978260429453825
# 0      0.031903635999043924  -0.16618591991719095
# 0      0.022579855832397598  -0.20121913837976765
# 0       0.02219777635685696  -0.22639421216412797
# 0       0.01805529145419006  -0.10666205072273985
# 0      0.030393104826917917  -0.19270177465413213
# 0       0.02296059263939485    -0.159502625875437

# %%
datos11=pd.read_csv('Prueba1.0.csv',decimal=",", encoding='utf-8',sep=u',')
datos12=pd.read_csv('Prueba2.0.csv',decimal=",",sep=u',', encoding='utf-8', dayfirst=True)
datos13=pd.read_csv('Prueba3.0.csv',decimal=",",sep=u',', encoding='utf-8', dayfirst=True)
datos14=pd.read_csv('Prueba4.0.csv',decimal=",",sep=u',', encoding='utf-8', dayfirst=True)
datos15=pd.read_csv('Prueba5.0.csv',decimal=",",sep=u',', encoding='utf-8', dayfirst=True)
datos16=pd.read_csv('Prueba6.0.csv',decimal=",",sep=u',', encoding='utf-8', dayfirst=True)
datos17=pd.read_csv('Prueba7.0.csv',decimal=",",sep=u',', encoding='utf-8',  dayfirst=True)
datos18=pd.read_csv('Prueba8.0.csv',decimal=",",sep=u',', encoding='utf-8', dayfirst=True)
datos19=pd.read_csv('Prueba9.0.csv',decimal=",",sep=u',', encoding='utf-8', dayfirst=True)
datos110=pd.read_csv('Prueba10.0.csv',decimal=",",sep=u',', encoding='utf-8',dayfirst=True)

# %%
datostotal1 = [datos11,datos12,datos13,datos14,datos15,datos16,datos17,datos18,datos19,datos110,]

# %%
resultadoDatos= pd.concat(datostotal1)

# %%
#resultadoDatos['Pruebas'] = resultadoDatos['Pruebas'].astype('float')
#resultadoDatos = resultadoDatos.set_index('Pruebas')

# %%
resultadoDatos
# Out:
#    Unnamed: 0 Pruebas      coef(a)_6am-MLP     rsquared_6am-MLP  \
# 0           0     1.0   0.4456671945280102   0.4090157412208374
# 0           0     2.0   0.4723163345909695   0.4611750003514494
# 0           0     3.0  0.29849825424263193   0.2753220269654497
# 0           0     4.0  0.35235571519416636   0.3178799661120091
# 0           0     5.0   0.3703547955736023   0.4168807726434368
# 0           0     6.0   0.5807812720216269   0.6191707482864894
# 0           0     7.0  0.48366421601477905   0.4313587842773734
# 0           0     8.0   0.3858964382324716    0.520826600558034
# 0           0     9.0   0.5657280490088086   0.3640493368535752
# 0           0    10.0   0.3096757796582197  0.23265536209319726
#
#   Standard Error_6am-MLP       coef(b)_6am-MLP coef(a)_Acu-6am-MLP  \
# 0    0.04850077660070194  0.021926056190888655  1.5134794451753903
# 0    0.04622149906740407  0.022548716869147535   1.257930530401092
# 0    0.04384437947490539  0.019291970629088162   0.824204969377049
# 0   0.046730475135120325   0.02133532940643004  1.0662837782202392
# 0     0.0396561740845295  0.019143558338553343  1.0079528626026075
# 0   0.041237527841171934  0.014917773942836377  1.0663604022855644
# 0    0.05027636677617236   0.02451123671789314   1.365263396806938
# 0    0.03351124843566247   0.02107506268858638  0.9901311629061855
# 0     0.0676954401601766  0.025542687911257644  1.5759816350271774
# 0    0.05091737237989807   0.02369520476419197  1.0345148355778728
#
#   rsquared_Acu-6am-MLP Standard Error_Acu-6am-MLP    coef(b)_Acu-6am-MLP  ...  \
# 0   0.9767220690521319       0.021153551897863374   -0.06396831419144496  ...
# 0   0.9863762207714906       0.013384564443811775    -0.2417842334437285  ...
# 0   0.9668207202854824       0.013823429945932915      0.440429034160457  ...
# 0   0.9713570989051648       0.016577228724893932    0.04511685823452814  ...
# 0   0.9906078072027498       0.008885726357912821    -0.0963193558264592  ...
# 0   0.9935466886741564       0.007780746419242556  -0.013579633046890235  ...
# 0   0.9764776274783107       0.019184299471951445    0.09160865939343885  ...
# 0   0.9733588507949162       0.014830397770210885   -0.33173648487850427  ...
# 0   0.9930537286149692       0.011933304875028016    0.14936220220009497  ...
# 0   0.9865668662190249       0.010929044993676171   -0.12909594559283072  ...
#
#   Standard Error_Acu-Beysens-PM coef(b)_Acu-Beysens-PM       coef(a)_MLP-PM  \
# 0          0.001806554210568118   0.061190618855122336  0.37712906334437507
# 0          0.008861270804363379   -0.11361461034997246   0.3514746327053534
# 0          0.005775438926020736     0.1801633947113131  0.14236103541033845
# 0         0.0021282761445212623  -0.030347118275098808  0.14834072084354635
# 0         0.0038616839537702445    -0.0746320023836067    0.269736859843713
# 0         0.0005738213039625364  -0.006457677123645946  0.25410612535322574
# 0         0.0017878058881236319  -0.014694520076000389   0.2654348926231349
# 0         0.0030015678464711776  -0.024164831458101048   0.2524727664849358
# 0          0.004145021895305277    0.10007528641573901   0.2631835789073723
# 0          0.008440671944148433    0.06675170766263719   0.1594460156153405
#
#        rsquared_MLP-PM Standard Error_MLP-PM        coef(b)_MLP-PM  \
# 0  0.31835609375004126   0.04996113625958348   0.02433171629290492
# 0   0.3252991546161882   0.04582772044512518  0.025733284543969656
# 0  0.14129662951787814   0.03177363104448534  0.021111113986667675
# 0  0.16055345801620624    0.0307091087464494  0.024913623989627813
# 0  0.22337985731407728   0.04553471902726079  0.026249599044355615
# 0   0.3036507836397755   0.03483866662891547  0.020339209189580675
# 0   0.2641571826330834   0.04010877367595514  0.028942503427036935
# 0   0.2920609874453197   0.03558736153427552   0.02391325412767508
# 0  0.26353741772396744   0.03983208509115784   0.02740988446375793
# 0  0.09951424472895287   0.04342397876057657  0.025575415962053833
#
#    coef(a)_Acu-MLP-PM rsquared_Acu-MLP-PM Standard Error_Acu-MLP-PM  \
# 0   1.501657938061236  0.9729719734062464      0.022659384278337132
# 0  1.2949690469468518  0.9775803112884041       0.01775489220311447
# 0  0.7192467112295704  0.9856886342528584       0.00784636733014378
# 0    1.03709826170248  0.9523885030230107      0.020993692859809357
# 0   1.250187835311698  0.9888114390171507      0.012039978965993351
# 0  0.8753675020182825  0.9889315817905894      0.008384364714378714
# 0  1.2586414006975677  0.9687439307128428      0.020468441725467405
# 0  1.0045529453575415  0.9757097766896242      0.014349882402097992
# 0   1.338837845221944   0.987748975370775       0.01349929152902101
# 0   1.136435794800355  0.9888583543919525      0.010921256761019304
#
#       coef(b)_Acu-MLP-PM
# 0    -0.1364527864039714
# 0    -0.3058243372286801
# 0    0.24936567814333033
# 0    0.07992677323195765
# 0    -0.1958388183978969
# 0   0.048338082353395775
# 0    0.14508807885198963
# 0    -0.2753452031799687
# 0  -0.007057878075074318
# 0   -0.23395638627670656
#
# [10 rows x 34 columns]

# %%
resultadoDatos = resultadoDatos.drop(['Unnamed: 0'], axis=1)

# %%
resultadoDatos
# Out:
#   Pruebas      coef(a)_6am-MLP     rsquared_6am-MLP Standard Error_6am-MLP  \
# 0     1.0   0.4456671945280102   0.4090157412208374    0.04850077660070194
# 0     2.0   0.4723163345909695   0.4611750003514494    0.04622149906740407
# 0     3.0  0.29849825424263193   0.2753220269654497    0.04384437947490539
# 0     4.0  0.35235571519416636   0.3178799661120091   0.046730475135120325
# 0     5.0   0.3703547955736023   0.4168807726434368     0.0396561740845295
# 0     6.0   0.5807812720216269   0.6191707482864894   0.041237527841171934
# 0     7.0  0.48366421601477905   0.4313587842773734    0.05027636677617236
# 0     8.0   0.3858964382324716    0.520826600558034    0.03351124843566247
# 0     9.0   0.5657280490088086   0.3640493368535752     0.0676954401601766
# 0    10.0   0.3096757796582197  0.23265536209319726    0.05091737237989807
#
#         coef(b)_6am-MLP coef(a)_Acu-6am-MLP rsquared_Acu-6am-MLP  \
# 0  0.021926056190888655  1.5134794451753903   0.9767220690521319
# 0  0.022548716869147535   1.257930530401092   0.9863762207714906
# 0  0.019291970629088162   0.824204969377049   0.9668207202854824
# 0   0.02133532940643004  1.0662837782202392   0.9713570989051648
# 0  0.019143558338553343  1.0079528626026075   0.9906078072027498
# 0  0.014917773942836377  1.0663604022855644   0.9935466886741564
# 0   0.02451123671789314   1.365263396806938   0.9764776274783107
# 0   0.02107506268858638  0.9901311629061855   0.9733588507949162
# 0  0.025542687911257644  1.5759816350271774   0.9930537286149692
# 0   0.02369520476419197  1.0345148355778728   0.9865668662190249
#
#   Standard Error_Acu-6am-MLP    coef(b)_Acu-6am-MLP coef(a)_6am-Beysens  ...  \
# 0       0.021153551897863374   -0.06396831419144496  0.6312825757001781  ...
# 0       0.013384564443811775    -0.2417842334437285  0.6548566833359228  ...
# 0       0.013823429945932915      0.440429034160457   0.550818934179782  ...
# 0       0.016577228724893932    0.04511685823452814  0.8161219102277297  ...
# 0       0.008885726357912821    -0.0963193558264592  0.7547430673364814  ...
# 0       0.007780746419242556  -0.013579633046890235  0.8449721695871559  ...
# 0       0.019184299471951445    0.09160865939343885  0.7739337277801743  ...
# 0       0.014830397770210885   -0.33173648487850427  0.5848816902392093  ...
# 0       0.011933304875028016    0.14936220220009497  0.9009247466989765  ...
# 0       0.010929044993676171   -0.12909594559283072   0.616384736220472  ...
#
#   Standard Error_Acu-Beysens-PM coef(b)_Acu-Beysens-PM       coef(a)_MLP-PM  \
# 0          0.001806554210568118   0.061190618855122336  0.37712906334437507
# 0          0.008861270804363379   -0.11361461034997246   0.3514746327053534
# 0          0.005775438926020736     0.1801633947113131  0.14236103541033845
# 0         0.0021282761445212623  -0.030347118275098808  0.14834072084354635
# 0         0.0038616839537702445    -0.0746320023836067    0.269736859843713
# 0         0.0005738213039625364  -0.006457677123645946  0.25410612535322574
# 0         0.0017878058881236319  -0.014694520076000389   0.2654348926231349
# 0         0.0030015678464711776  -0.024164831458101048   0.2524727664849358
# 0          0.004145021895305277    0.10007528641573901   0.2631835789073723
# 0          0.008440671944148433    0.06675170766263719   0.1594460156153405
#
#        rsquared_MLP-PM Standard Error_MLP-PM        coef(b)_MLP-PM  \
# 0  0.31835609375004126   0.04996113625958348   0.02433171629290492
# 0   0.3252991546161882   0.04582772044512518  0.025733284543969656
# 0  0.14129662951787814   0.03177363104448534  0.021111113986667675
# 0  0.16055345801620624    0.0307091087464494  0.024913623989627813
# 0  0.22337985731407728   0.04553471902726079  0.026249599044355615
# 0   0.3036507836397755   0.03483866662891547  0.020339209189580675
# 0   0.2641571826330834   0.04010877367595514  0.028942503427036935
# 0   0.2920609874453197   0.03558736153427552   0.02391325412767508
# 0  0.26353741772396744   0.03983208509115784   0.02740988446375793
# 0  0.09951424472895287   0.04342397876057657  0.025575415962053833
#
#    coef(a)_Acu-MLP-PM rsquared_Acu-MLP-PM Standard Error_Acu-MLP-PM  \
# 0   1.501657938061236  0.9729719734062464      0.022659384278337132
# 0  1.2949690469468518  0.9775803112884041       0.01775489220311447
# 0  0.7192467112295704  0.9856886342528584       0.00784636733014378
# 0    1.03709826170248  0.9523885030230107      0.020993692859809357
# 0   1.250187835311698  0.9888114390171507      0.012039978965993351
# 0  0.8753675020182825  0.9889315817905894      0.008384364714378714
# 0  1.2586414006975677  0.9687439307128428      0.020468441725467405
# 0  1.0045529453575415  0.9757097766896242      0.014349882402097992
# 0   1.338837845221944   0.987748975370775       0.01349929152902101
# 0   1.136435794800355  0.9888583543919525      0.010921256761019304
#
#       coef(b)_Acu-MLP-PM
# 0    -0.1364527864039714
# 0    -0.3058243372286801
# 0    0.24936567814333033
# 0    0.07992677323195765
# 0    -0.1958388183978969
# 0   0.048338082353395775
# 0    0.14508807885198963
# 0    -0.2753452031799687
# 0  -0.007057878075074318
# 0   -0.23395638627670656
#
# [10 rows x 33 columns]

# %%
resultadoDatos=resultadoDatos.astype(float)

# %%
resultadoDatos
# Out:
#    Pruebas  coef(a)_6am-MLP  rsquared_6am-MLP  Standard Error_6am-MLP  \
# 0      1.0         0.445667          0.409016                0.048501
# 0      2.0         0.472316          0.461175                0.046221
# 0      3.0         0.298498          0.275322                0.043844
# 0      4.0         0.352356          0.317880                0.046730
# 0      5.0         0.370355          0.416881                0.039656
# 0      6.0         0.580781          0.619171                0.041238
# 0      7.0         0.483664          0.431359                0.050276
# 0      8.0         0.385896          0.520827                0.033511
# 0      9.0         0.565728          0.364049                0.067695
# 0     10.0         0.309676          0.232655                0.050917
#
#    coef(b)_6am-MLP  coef(a)_Acu-6am-MLP  rsquared_Acu-6am-MLP  \
# 0         0.021926             1.513479              0.976722
# 0         0.022549             1.257931              0.986376
# 0         0.019292             0.824205              0.966821
# 0         0.021335             1.066284              0.971357
# 0         0.019144             1.007953              0.990608
# 0         0.014918             1.066360              0.993547
# 0         0.024511             1.365263              0.976478
# 0         0.021075             0.990131              0.973359
# 0         0.025543             1.575982              0.993054
# 0         0.023695             1.034515              0.986567
#
#    Standard Error_Acu-6am-MLP  coef(b)_Acu-6am-MLP  coef(a)_6am-Beysens  ...  \
# 0                    0.021154            -0.063968             0.631283  ...
# 0                    0.013385            -0.241784             0.654857  ...
# 0                    0.013823             0.440429             0.550819  ...
# 0                    0.016577             0.045117             0.816122  ...
# 0                    0.008886            -0.096319             0.754743  ...
# 0                    0.007781            -0.013580             0.844972  ...
# 0                    0.019184             0.091609             0.773934  ...
# 0                    0.014830            -0.331736             0.584882  ...
# 0                    0.011933             0.149362             0.900925  ...
# 0                    0.010929            -0.129096             0.616385  ...
#
#    Standard Error_Acu-Beysens-PM  coef(b)_Acu-Beysens-PM  coef(a)_MLP-PM  \
# 0                       0.001807                0.061191        0.377129
# 0                       0.008861               -0.113615        0.351475
# 0                       0.005775                0.180163        0.142361
# 0                       0.002128               -0.030347        0.148341
# 0                       0.003862               -0.074632        0.269737
# 0                       0.000574               -0.006458        0.254106
# 0                       0.001788               -0.014695        0.265435
# 0                       0.003002               -0.024165        0.252473
# 0                       0.004145                0.100075        0.263184
# 0                       0.008441                0.066752        0.159446
#
#    rsquared_MLP-PM  Standard Error_MLP-PM  coef(b)_MLP-PM  coef(a)_Acu-MLP-PM  \
# 0         0.318356               0.049961        0.024332            1.501658
# 0         0.325299               0.045828        0.025733            1.294969
# 0         0.141297               0.031774        0.021111            0.719247
# 0         0.160553               0.030709        0.024914            1.037098
# 0         0.223380               0.045535        0.026250            1.250188
# 0         0.303651               0.034839        0.020339            0.875368
# 0         0.264157               0.040109        0.028943            1.258641
# 0         0.292061               0.035587        0.023913            1.004553
# 0         0.263537               0.039832        0.027410            1.338838
# 0         0.099514               0.043424        0.025575            1.136436
#
#    rsquared_Acu-MLP-PM  Standard Error_Acu-MLP-PM  coef(b)_Acu-MLP-PM
# 0             0.972972                   0.022659           -0.136453
# 0             0.977580                   0.017755           -0.305824
# 0             0.985689                   0.007846            0.249366
# 0             0.952389                   0.020994            0.079927
# 0             0.988811                   0.012040           -0.195839
# 0             0.988932                   0.008384            0.048338
# 0             0.968744                   0.020468            0.145088
# 0             0.975710                   0.014350           -0.275345
# 0             0.987749                   0.013499           -0.007058
# 0             0.988858                   0.010921           -0.233956
#
# [10 rows x 33 columns]

# %%
#mean_df = df['R-cuadrado-Modelo-Beysens(6am)'].mean()
#print(mean_df)

# %% [markdown]
# # Resultados de Pruebas a modelo test

# %%
import matplotlib.pyplot as plt

# %%
#Graficos

# %% [markdown]
# ## grafico 1, modelo R cuadrado

# %%
fig, ax = plt.subplots(figsize=(8,6))   


pruebas= resultadoDatos['Pruebas']
resultados={'Modelo Beysens(6am)':resultadoDatos['rsquared_6am-Beysens'],'Modelo RNA(6am)':resultadoDatos['rsquared_6am-MLP']}
ax.plot(pruebas,resultados['Modelo Beysens(6am)'], marker ='^',label="Modelo-Beysens(6am)")
ax.plot(pruebas,resultados['Modelo RNA(6am)'], marker = 'o',label="Modelo-MLP(6am)")
plt.ylabel('Resultado R cuadrado')
plt.xlabel('Cantidad de Pruebas')
legend = ax.legend(loc="best")  
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/matplotlib/cbook/__init__.py:1377: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x[:, None]
# /usr/local/lib/python3.6/dist-packages/matplotlib/axes/_base.py:237: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x = x[:, np.newaxis]
# /usr/local/lib/python3.6/dist-packages/matplotlib/axes/_base.py:239: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   y = y[:, np.newaxis]

# %%
mean_df1 = resultadoDatos['rsquared_6am-Beysens'].mean()
print(mean_df1)
# Out:
# 0.39365574772149964

# %%
mean_df = resultadoDatos['rsquared_6am-MLP'].mean()
print(mean_df)
# Out:
# 0.4048334339361852

# %%
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['rsquared_6am-Beysens']))
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['rsquared_6am-MLP']))
# Out:
# 0.09632900253515532
# 0.1150257152444455

# %% [markdown]
# ## m

# %%
fig, ax = plt.subplots(figsize=(8,6))   


pruebas= resultadoDatos['Pruebas']
resultados={'Modelo Beysens(6am)':resultadoDatos['coef(a)_6am-Beysens'],'Modelo RNA(6am)':resultadoDatos['coef(a)_6am-MLP']}
ax.plot(pruebas,resultados['Modelo Beysens(6am)'], marker ='^',label="m del Modelo-Beysens(6am)")
ax.plot(pruebas,resultados['Modelo RNA(6am)'], marker = 'o',label="m del Modelo-MLP(6am)")
plt.ylabel('Resultado pendiente')
plt.xlabel('Cantidad de Pruebas')
legend = ax.legend(loc="best")  
plt.show()

# %%
mean_df111 = resultadoDatos['coef(a)_6am-Beysens'].mean()
print(mean_df111)
# Out:
# 0.7128920241306083

# %%
mean_df = resultadoDatos['coef(a)_6am-MLP'].mean()
print(mean_df)
# Out:
# 0.4264938049065286

# %%
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['coef(a)_6am-Beysens']))
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['coef(a)_6am-MLP']))
# Out:
# 0.12061493822584608
# 0.09958362156203084

# %% [markdown]
# ## coef

# %%
fig, ax = plt.subplots(figsize=(8,6))   


pruebas= resultadoDatos['Pruebas']
resultados={'Modelo Beysens(6am)':resultadoDatos['coef(b)_6am-Beysens'],'Modelo RNA(6am)':resultadoDatos['coef(b)_6am-MLP']}
ax.plot(pruebas,resultados['Modelo Beysens(6am)'], marker ='^',label="Coef b del Modelo-Beysens(6am)")
ax.plot(pruebas,resultados['Modelo RNA(6am)'], marker = 'o',label="Coef b del Modelo-MLP(6am)")
plt.ylabel('Resultado coef')
plt.xlabel('Cantidad de Pruebas')
legend = ax.legend(loc="best")  
plt.show()

# %%
mean_df1145 = resultadoDatos['coef(b)_6am-Beysens'].mean()
print(mean_df1145)
# Out:
# 0.012259208100209452

# %%
mean_df1245 = resultadoDatos['coef(b)_6am-MLP'].mean()
print(mean_df1245)
# Out:
# 0.021398759745887324

# %%
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['coef(b)_6am-Beysens']))
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['coef(b)_6am-MLP']))
# Out:
# 0.003309742098621637
# 0.003079867063002008

# %% [markdown]
# ## error

# %%
fig, ax = plt.subplots(figsize=(8,6))   


pruebas= resultadoDatos['Pruebas']
resultados={'Modelo Beysens(6am)':resultadoDatos['Standard Error_6am-Beysens'],'Modelo RNA(6am)':resultadoDatos['Standard Error_6am-MLP']}
ax.plot(pruebas,resultados['Modelo Beysens(6am)'], marker ='^',label="Standard Error del Modelo-Beysens(6am)")
ax.plot(pruebas,resultados['Modelo RNA(6am)'], marker = 'o',label="Standard Error del Modelo-MLP(6am)")
plt.ylabel('Resultados de Standard Error')
plt.xlabel('Cantidad de Pruebas')
legend = ax.legend(loc="best")  
plt.show()

# %%
mean_df114 = resultadoDatos['Standard Error_6am-Beysens'].mean()
print(mean_df114)
# Out:
# 0.08023140706594026

# %%
mean_df124 = resultadoDatos['Standard Error_6am-MLP'].mean()
print(mean_df124)
# Out:
# 0.04685912599557426

# %%
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['Standard Error_6am-Beysens']))
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['Standard Error_6am-MLP']))
# Out:
# 0.01076500399338504
# 0.009044067644765775

# %% [markdown]
# ## grafico 2

# %%
fig, ax = plt.subplots(figsize=(8,6)) 

pruebas= resultadoDatos['Pruebas']
resultados={'Modelo Beysens(6am)':resultadoDatos['rsquared_Acu-6am-Beysens'],'Modelo RNA(6am)':resultadoDatos['rsquared_Acu-6am-MLP']}
ax.plot(pruebas,resultados['Modelo Beysens(6am)'], marker ='^',label="rsquaredModelo-Acumulado-Beysens(6am)")
ax.plot(pruebas,resultados['Modelo RNA(6am)'], marker = 'o',label="rsquaredModelo-Acumulado-MLP(6am)")
plt.ylabel('Resultados R cuadrado acumulado')
plt.xlabel('Cantidad de Pruebas')
legend = ax.legend(loc="best")  
plt.show()

# %%
mean_df11 = resultadoDatos['rsquared_Acu-6am-Beysens'].mean()
print(mean_df11)
# Out:
# 0.9775017933444505

# %%
mean_df11 = resultadoDatos['rsquared_Acu-6am-MLP'].mean()
print(mean_df11)
# Out:
# 0.9814887677998397

# %%
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['rsquared_Acu-6am-Beysens']))
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['rsquared_Acu-6am-MLP']))
# Out:
# 0.016008300444498542
# 0.009682193056550227

# %% [markdown]
# ## m

# %%
fig, ax = plt.subplots(figsize=(8,6))   


pruebas= resultadoDatos['Pruebas']
resultados={'Modelo Beysens(6am)':resultadoDatos['coef(a)_Acu-6am-Beysens'],'Modelo RNA(6am)':resultadoDatos['coef(a)_Acu-6am-MLP']}
ax.plot(pruebas,resultados['Modelo Beysens(6am)'], marker ='^',label="m del Modelo-Acumulado-Beysens(6am)")
ax.plot(pruebas,resultados['Modelo RNA(6am)'], marker = 'o',label="m del Modelo-Acumulado-MLP(6am)")
plt.ylabel('Resultados m')
plt.xlabel('Cantidad de Pruebas')
legend = ax.legend(loc="best")  
plt.show()

# %%
mean_df11112 = resultadoDatos['coef(a)_Acu-6am-Beysens'].mean()
print(mean_df11112)
# Out:
# 1.1355993723047049

# %%
mean_df11111 = resultadoDatos['coef(a)_Acu-6am-MLP'].mean()
print(mean_df11111)
# Out:
# 1.1702103018380117

# %%
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['coef(a)_Acu-6am-Beysens']))
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['coef(a)_Acu-6am-MLP']))
# Out:
# 0.15469749092491306
# 0.24646367197503802

# %% [markdown]
# ## coef

# %%
fig, ax = plt.subplots(figsize=(8,6))   


pruebas= resultadoDatos['Pruebas']
resultados={'Modelo Beysens(6am)':resultadoDatos['coef(b)_Acu-6am-Beysens'],'Modelo RNA(6am)':resultadoDatos['coef(b)_Acu-6am-MLP']}
ax.plot(pruebas,resultados['Modelo Beysens(6am)'], marker ='^',label="Coef del Modelo-Acumulado-Beysens(6am)")
ax.plot(pruebas,resultados['Modelo RNA(6am)'], marker = 'o',label="Coef del Modelo-Acumulado-MLP(6am)")
plt.ylabel('Resultados coef')
plt.xlabel('Cantidad de Pruebas')
legend = ax.legend(loc="best")  
plt.show()

# %%
mean_df63 = resultadoDatos['coef(b)_Acu-6am-Beysens'].mean()
print(mean_df63)
# Out:
# -0.017744429420844726

# %%
mean_df64= resultadoDatos['coef(b)_Acu-6am-MLP'].mean()
print(mean_df64)
# Out:
# -0.014996721299133894

# %%
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['coef(b)_Acu-6am-Beysens']))
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['coef(b)_Acu-6am-MLP']))
# Out:
# 0.29607350076094363
# 0.21684446718127667

# %% [markdown]
# ## error

# %%
fig, ax = plt.subplots(figsize=(8,6))   


pruebas1= resultadoDatos['Pruebas']
resultados1={'Modelo Beysens(6am)':resultadoDatos['Standard Error_Acu-6am-Beysens'],'Modelo RNA(6am)':resultadoDatos['Standard Error_Acu-6am-MLP']}
ax.plot(pruebas1,resultados1['Modelo Beysens(6am)'], marker ='^',label="Standard Error del Modelo-Beysens(6am)")
ax.plot(pruebas1,resultados1['Modelo RNA(6am)'], marker = 'o',label="Standard Error del Modelo-MLP(6am)")
plt.ylabel('Resultados de los errores')
plt.xlabel('Cantidad de Pruebas')
legend = ax.legend(loc="best")  
plt.show()

# %%
mean_df6 = resultadoDatos['Standard Error_Acu-6am-Beysens'].mean()
print(mean_df6)
# Out:
# 0.014498485135183859

# %%
mean_df6 = resultadoDatos['Standard Error_Acu-6am-MLP'].mean()
print(mean_df6)
# Out:
# 0.013848229490052391

# %%
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['Standard Error_Acu-6am-Beysens']))
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['rsquared_Beysens-PM']))
# Out:
# 0.00412151767271176
# 0.026028302752137113

# %% [markdown]
# ## grafico 3

# %%
fig, ax = plt.subplots(figsize=(8,6)) 

pruebas= resultadoDatos['Pruebas']
resultados={'Modelo Beysens(PM)':resultadoDatos['rsquared_Beysens-PM'],'Modelo RNA(PM)':resultadoDatos['rsquared_MLP-PM']}
ax.plot(pruebas,resultados['Modelo Beysens(PM)'], marker ='^',label="rsquaredModelo-Beysens(PM)")
ax.plot(pruebas,resultados['Modelo RNA(PM)'], marker = 'o',label="rsquaredModelo-MLP(PM)")
plt.ylabel('Resultado R cuadrado')
plt.xlabel('Cantidad de Pruebas')
legend = ax.legend(loc="best")  
plt.show()

# %%
mean_df6 = resultadoDatos['rsquared_Beysens-PM'].mean()
print(mean_df6)
# Out:
# 0.024268264589993715

# %%
mean_df7 = resultadoDatos['rsquared_MLP-PM'].mean()
print(mean_df7)
# Out:
# 0.23918058093854894

# %%
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['rsquared_Beysens-PM']))
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['rsquared_MLP-PM']))
# Out:
# 0.026028302752137113
# 0.07984348708033567

# %% [markdown]
# ## m

# %%
fig, ax = plt.subplots(figsize=(8,6))   
#rsquared

pruebas= resultadoDatos['Pruebas']
resultados={'Modelo Beysens(6am)':resultadoDatos['coef(a)_Beysens-PM'],'Modelo RNA(6am)':resultadoDatos['coef(a)_MLP-PM']}
ax.plot(pruebas,resultados['Modelo Beysens(6am)'], marker ='^',label="m del Modelo-Beysens(PM)")
ax.plot(pruebas,resultados['Modelo RNA(6am)'], marker = 'o',label="m del Modelo-MLP(PM)")
plt.ylabel('Resultados pendientes')
plt.xlabel('Cantidad de Pruebas')
legend = ax.legend(loc="best")  
plt.show()

# %%
mean_df77 = resultadoDatos['coef(a)_Beysens-PM'].mean()
print(mean_df77)
# Out:
# -0.00023154682641697227

# %%
mean_df78 = resultadoDatos['coef(a)_MLP-PM'].mean()
print(mean_df78)
# Out:
# 0.24836856911313357

# %%
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['coef(a)_Beysens-PM']))
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['coef(a)_MLP-PM']))
# Out:
# 0.0023273141824794374
# 0.07984542366743523

# %% [markdown]
# ## coef

# %%
fig, ax = plt.subplots(figsize=(8,6))   
#rsquared

pruebas= resultadoDatos['Pruebas']
resultados={'Modelo Beysens(6am)':resultadoDatos['coef(b)_Beysens-PM'],'Modelo RNA(6am)':resultadoDatos['coef(b)_MLP-PM']}
ax.plot(pruebas,resultados['Modelo Beysens(6am)'], marker ='^',label="Coef del Modelo-Beysens(PM)")
ax.plot(pruebas,resultados['Modelo RNA(6am)'], marker = 'o',label="Coef del Modelo-MLP(PM)")
plt.ylabel('Resultados coef b')
plt.xlabel('Cantidad de Pruebas')
legend = ax.legend(loc="best")  
plt.show()

# %%
mean_df781 = resultadoDatos['coef(b)_Beysens-PM'].mean()
print(mean_df781)
# Out:
# 0.002926793634278125

# %%
mean_df786 = resultadoDatos['coef(b)_MLP-PM'].mean()
print(mean_df786)
# Out:
# 0.02485196050276301

# %%
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['coef(b)_Beysens-PM']))
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['coef(b)_MLP-PM']))
# Out:
# 0.005078102336249443
# 0.0026255901541777536

# %% [markdown]
# ## error

# %%
fig, ax = plt.subplots(figsize=(8,6))   
#rsquared

pruebas= resultadoDatos['Pruebas']
resultados={'Modelo Beysens(6am)':resultadoDatos['Standard Error_Beysens-PM'],'Modelo RNA(6am)':resultadoDatos['Standard Error_MLP-PM']}
ax.plot(pruebas,resultados['Modelo Beysens(6am)'], marker ='^',label="m del Modelo-Beysens(PM)")
ax.plot(pruebas,resultados['Modelo RNA(6am)'], marker = 'o',label="m del Modelo-MLP(PM)")
plt.ylabel('Resultados Standard Error')
plt.xlabel('Cantidad de Pruebas')
legend = ax.legend(loc="best")  
plt.show()

# %%
mean_df7864 = resultadoDatos['Standard Error_Beysens-PM'].mean()
print(mean_df7864)
# Out:
# 0.0012893229766006273

# %%
mean_df7865 = resultadoDatos['Standard Error_MLP-PM'].mean()
print(mean_df7865)
# Out:
# 0.039759718121378476

# %%
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['Standard Error_Beysens-PM']))
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['Standard Error_MLP-PM']))
# Out:
# 0.0006608680524056885
# 0.006455923435312848

# %% [markdown]
# ## grafico 4

# %%
fig, ax = plt.subplots(figsize=(8,6)) 

pruebas= resultadoDatos['Pruebas']
resultados={'Modelo Beysens(PM)':resultadoDatos['rsquared_Acu-Beysens-PM'],'Modelo RNA(PM)':resultadoDatos['rsquared_Acu-MLP-PM']}
ax.plot(pruebas,resultados['Modelo Beysens(PM)'], marker ='^',label="rsquaredModelo-Acumulado-Beysens(PM)")
ax.plot(pruebas,resultados['Modelo RNA(PM)'], marker = 'o',label="rsquaredModelo-Acumulado-MLP(PM)")
plt.ylabel('Resultado R cuadrado')
plt.xlabel('Cantidad de Pruebas')
legend = ax.legend(loc="best")  
plt.show()

# %%
mean_df8 = resultadoDatos['rsquared_Acu-Beysens-PM'].mean()
print(mean_df8)
# Out:
# 0.6212049442158637

# %%
mean_df9 = resultadoDatos['rsquared_Acu-MLP-PM'].mean()
print(mean_df9)
# Out:
# 0.9787433479943454

# %%
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['rsquared_Acu-Beysens-PM']))
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['rsquared_Acu-MLP-PM']))
# Out:
# 0.24986566324082582
# 0.011903540174245495

# %% [markdown]
# ## m

# %%
fig, ax = plt.subplots(figsize=(8,6))   
#rsquared

pruebas= resultadoDatos['Pruebas']
resultados={'Modelo Beysens(6am)':resultadoDatos['coef(a)_Acu-Beysens-PM'],'Modelo RNA(6am)':resultadoDatos['coef(a)_Acu-MLP-PM']}
ax.plot(pruebas,resultados['Modelo Beysens(6am)'], marker ='^',label="m del Modelo-Acu-Beysens(PM)")
ax.plot(pruebas,resultados['Modelo RNA(6am)'], marker = 'o',label="m del Modelo-Acu-MLP(PM)")
plt.ylabel('Resultados pendientes')
plt.xlabel('Cantidad de Pruebas')
legend = ax.legend(loc="best")  
plt.show()

# %%
mean_df78649 = resultadoDatos['coef(a)_Acu-Beysens-PM'].mean()
print(mean_df78649)
# Out:
# 0.07651979278134764

# %%
mean_df78648 = resultadoDatos['coef(a)_Acu-MLP-PM'].mean()
print(mean_df78648)
# Out:
# 1.1416995281347524

# %%
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['coef(a)_Acu-Beysens-PM']))
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['coef(a)_Acu-MLP-PM']))
# Out:
# 0.06248186050586067
# 0.2348871313659739

# %% [markdown]
# ## coef

# %%
fig, ax = plt.subplots(figsize=(8,6))   
#rsquared

pruebas= resultadoDatos['Pruebas']
resultados={'Modelo Beysens(6am)':resultadoDatos['coef(b)_Acu-Beysens-PM'],'Modelo RNA(6am)':resultadoDatos['coef(b)_Acu-MLP-PM']}
ax.plot(pruebas,resultados['Modelo Beysens(6am)'], marker ='^',label="Coef del Modelo-Acu-Beysens(PM)")
ax.plot(pruebas,resultados['Modelo RNA(6am)'], marker = 'o',label="Coef del Modelo-Acu-MLP(PM)")
plt.ylabel('Resultados coef b')
plt.xlabel('Cantidad de Pruebas')
legend = ax.legend(loc="best")  
plt.show()

# %%
mean_df786489 = resultadoDatos['coef(b)_Acu-Beysens-PM'].mean()
print(mean_df786489)
# Out:
# 0.014427024797838629

# %%
mean_df786489 = resultadoDatos['coef(b)_Acu-MLP-PM'].mean()
print(mean_df786489)
# Out:
# -0.06317567969816246

# %%
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['coef(b)_Acu-Beysens-PM']))
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['coef(b)_Acu-MLP-PM']))
# Out:
# 0.08745369330714041
# 0.19239661075772113

# %% [markdown]
# ## error

# %%
fig, ax = plt.subplots(figsize=(8,6))   
#rsquared

pruebas= resultadoDatos['Pruebas']
resultados={'Modelo Beysens(6am)':resultadoDatos['Standard Error_Acu-Beysens-PM'],'Modelo RNA(6am)':resultadoDatos['Standard Error_Acu-MLP-PM']}
ax.plot(pruebas,resultados['Modelo Beysens(6am)'], marker ='^',label="Standard Error_ del Modelo-Beysens(PM)")
ax.plot(pruebas,resultados['Modelo RNA(6am)'], marker = 'o',label="Standard Error_ del Modelo-MLP(PM)")
plt.ylabel('Resultados Standard Error')
plt.xlabel('Cantidad de Pruebas')
legend = ax.legend(loc="best")  
plt.show()

# %%
mean_df7864899 = resultadoDatos['Standard Error_Acu-Beysens-PM'].mean()
print(mean_df7864899)
# Out:
# 0.00403821129172548

# %%
mean_df78648999 = resultadoDatos['Standard Error_Acu-MLP-PM'].mean()
print(mean_df78648999)
# Out:
# 0.014891755276938251

# %%
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['Standard Error_Acu-Beysens-PM']))
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['Standard Error_Acu-MLP-PM']))
# Out:
# 0.0028377062492420807
# 0.005322701681589159

# %% [markdown]
# ## 1

# %%
fig, ax = plt.subplots(figsize=(8,6)) 

pruebas= resultadoDatos['Pruebas']
resultados={'Modelo Beysens(6am)':resultadoDatos['rsquared_Acu-6am-Beysens'],'Modelo RNA(6am)':resultadoDatos['rsquared_Acu-6am-MLP'],'Modelo Beysens(PM)':resultadoDatos['rsquared_Acu-Beysens-PM'],'Modelo RNA(PM)':resultadoDatos['rsquared_Acu-MLP-PM']}
ax.plot(pruebas,resultados['Modelo Beysens(6am)'], marker ='^',label="Modelo-Acumulado-Beysens(6am)")
ax.plot(pruebas,resultados['Modelo RNA(6am)'], marker = 'o',label="Modelo-Acumulado-MLP(6am)")
ax.plot(pruebas,resultados['Modelo Beysens(PM)'], marker ='^',label="Modelo-Acumulado-Beysens(PM)")
ax.plot(pruebas,resultados['Modelo RNA(PM)'], marker = 'o',label="Modelo-Acumulado-MLP(PM)")
plt.ylabel('Resultados R cuadrado acumulado')
plt.xlabel('Cantidad de Pruebas')
legend = ax.legend(loc="best")  
plt.show()

# %%
fig, ax = plt.subplots(figsize=(8,6)) 

pruebas= resultadoDatos['Pruebas']
resultados={'Modelo Beysens(6am)':resultadoDatos['rsquared_Acu-6am-Beysens'],'Modelo RNA(6am)':resultadoDatos['rsquared_Acu-6am-MLP'],'Modelo Beysens(PM)':resultadoDatos['rsquared_Acu-Beysens-PM'],'Modelo RNA(PM)':resultadoDatos['rsquared_Acu-MLP-PM']}
ax.plot(pruebas,resultados['Modelo Beysens(6am)'], marker ='^',label="Modelo-Acumulado-Beysens(6am)")
ax.plot(pruebas,resultados['Modelo RNA(6am)'], marker = 'o',label="Modelo-Acumulado-MLP(6am)")
#ax.plot(pruebas,resultados['Modelo Beysens(PM)'], marker ='^',label="Modelo-Acumulado-Beysens(PM)")
ax.plot(pruebas,resultados['Modelo RNA(PM)'],c='red', marker = 'o',label="Modelo-Acumulado-MLP(PM)")
plt.ylabel('Resultados R cuadrado acumulado')
plt.xlabel('Cantidad de Pruebas')
legend = ax.legend(loc="best")  
plt.show()

# %%
fig, ax = plt.subplots(figsize=(8,6)) 

pruebas= resultadoDatos['Pruebas']
resultados={'Modelo Beysens(6am)':resultadoDatos['coef(a)_Acu-6am-Beysens'],'Modelo RNA(6am)':resultadoDatos['coef(a)_Acu-6am-MLP'],'Modelo Beysens(PM)':resultadoDatos['coef(a)_Acu-Beysens-PM'],'Modelo RNA(PM)':resultadoDatos['coef(a)_Acu-MLP-PM']}
ax.plot(pruebas,resultados['Modelo Beysens(6am)'], marker ='^',label="M Modelo-Acumulado-Beysens(6am)")
ax.plot(pruebas,resultados['Modelo RNA(6am)'], marker = 'o',label="M Modelo-Acumulado-MLP(6am)")
ax.plot(pruebas,resultados['Modelo Beysens(PM)'], marker ='^',label="Modelo-Acumulado-Beysens(PM)")
ax.plot(pruebas,resultados['Modelo RNA(PM)'],c='red', marker = 'o',label="M Modelo-Acumulado-MLP(PM)")
plt.ylabel('Resultados R cuadrado acumulado')
plt.xlabel('Cantidad de Pruebas')
legend = ax.legend(loc="best")  
plt.show()

# %%
#cambiar 
#resultado6=pd.merge(df5, df6, on='Pruebas', suffixes=('_Beysens-PM', '_Acu-Beysens-PM'))

# %% [markdown]
# resultados con modelo LM
